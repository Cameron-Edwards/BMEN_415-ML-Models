# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt  
import seaborn as sns 
import os
from sklearn import datasets
from sklearn.metrics import confusion_matrix, mean_squared_error, mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_predict  
from math import sqrt  # For squareroot operation

# %%
data = pd.read_csv("vol_feature.csv")
data
# Out:
#       S.No  Left-Lateral-Ventricle  Left-Inf-Lat-Vent  \
# 0        1                 22916.9              982.7
# 1        2                 22953.2              984.5
# 2        3                 23320.4             1062.1
# 3        4                 24360.0             1000.5
# 4        5                 25769.4             1124.4
# ...    ...                     ...                ...
# 4221  4222                 27065.6              532.4
# 4222  4223                 28408.8              912.7
# 4223  4224                 34467.9             1659.6
# 4224  4225                 31627.5             1334.4
# 4225  4226                 14879.4              704.2
#
#       Left-Cerebellum-White-Matter  Left-Cerebellum-Cortex  Left-Thalamus  \
# 0                          15196.7                 55796.4         6855.5
# 1                          15289.7                 55778.6         6835.1
# 2                          15382.1                 55551.2         7566.0
# ...

# %%
data.info()
data.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4226 entries, 0 to 4225
# Columns: 141 entries, S.No to dataset
# dtypes: float64(122), int64(19)
# memory usage: 4.5 MB
# (4226, 141)

# %%
data.drop('S.No', axis=1, inplace=True)
data.drop('dataset', axis = 1, inplace=True)

# %%
data.describe()
# Out:
#        Left-Lateral-Ventricle  Left-Inf-Lat-Vent  \
# count             4226.000000        4226.000000
# mean             13370.040795         574.849716
# std               9194.928348         594.590387
# min               2204.100000           0.000000
# 25%               7031.625000         243.200000
# 50%              10669.950000         385.800000
# 75%              17332.650000         720.825000
# max              79812.500000        7533.800000
#
#        Left-Cerebellum-White-Matter  Left-Cerebellum-Cortex  Left-Thalamus  \
# count                   4226.000000             4226.000000    4226.000000
# mean                   14646.696711            52002.811571    7164.947539
# std                     2622.868798             6378.435917    1207.229615
# min                     6920.100000            29911.800000    4145.400000
# 25%                    12909.875000            47359.675000    6239.425000
# ...

# %%
data.corr()
# Out:
#                               Left-Lateral-Ventricle  Left-Inf-Lat-Vent  \
# Left-Lateral-Ventricle                      1.000000           0.758895
# Left-Inf-Lat-Vent                           0.758895           1.000000
# Left-Cerebellum-White-Matter               -0.185344          -0.185624
# Left-Cerebellum-Cortex                     -0.115200          -0.114728
# Left-Thalamus                              -0.339383          -0.324770
# ...                                              ...                ...
# rh_insula_thickness                        -0.399022          -0.388870
# rh_MeanThickness_thickness                 -0.473704          -0.460625
# BrainSegVolNotVent.2                       -0.143671          -0.178073
# eTIV.1                                      0.311918           0.171763
# Age                                         0.569539           0.496304
#
#                               Left-Cerebellum-White-Matter  \
# ...

# %%
Y = data.Age
X = data.drop('Age', axis=1)
X_numpy=X.to_numpy()
Y_numpy=Y.to_numpy()
X.shape, Y.shape
# Out:
# ((4226, 138), (4226,))

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X_numpy,Y_numpy, test_size= 0.2)

x_train.shape, y_train.shape
# Out:
# ((3380, 138), (3380,))

# %% [markdown]
# Model 1 : Multiple Linear Regression

# %%
from sklearn.linear_model import LinearRegression

model_1 = LinearRegression(fit_intercept=True)
model_1.fit(x_train, y_train)
y_pred_LR_train = model_1.predict(x_train)
y_pred_LR_test = model_1.predict(x_test)

# %%
RMSE_LR_train = sqrt(mean_squared_error(y_train, y_pred_LR_train))
print("RMSE for Training Data: ", RMSE_LR_train)

RMSE_LR_test = sqrt(mean_squared_error(y_test, y_pred_LR_test))
print("RMSE for Testing Data: ", RMSE_LR_test)

print('MSE:', mean_squared_error(y_test, y_pred_LR_test))
print('MAE:', mean_absolute_error(y_test, y_pred_LR_test))

print('Coefficient of determination (R^2)for Testing: %.2f'
        % r2_score(y_test, y_pred_LR_test))
print('Coefficient of determination (R^2)for training: %.2f'
        % r2_score(y_train, y_pred_LR_train))
# Out:
# RMSE for Training Data:  7.467707487843946
# RMSE for Testing Data:  7.713251897179996
# MSE: 59.4942548293508
# MAE: 6.0794957290663545
# Coefficient of determination (R^2)for Testing: 0.86
# Coefficient of determination (R^2)for training: 0.86

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(y_train, y_pred_LR_train, alpha=1.0)
plt.plot([y_train.min(), y_train.max()], [y_train.min(), y_train.max()], 'k--', color='red', lw = 3)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Training Data')
# Out:
# C:\Users\kunsa\AppData\Local\Programs\Python\Python36\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Training Data')

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(y_test, y_pred_LR_test, alpha=1.0, marker="*")
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', color='red', lw = 3)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Testing Data')
# Out:
# C:\Users\kunsa\AppData\Local\Programs\Python\Python36\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Testing Data')

# %% [markdown]
# Model 2: Partial Least Squares Model

# %%
from sklearn.cross_decomposition import PLSRegression
model_2= PLSRegression(n_components=2)
model_2.fit(x_train, y_train)
PLSRegression()
Prediction_2 = model_2.predict(x_test)

# %%
print('MSE:', mean_squared_error(y_test, Prediction_2))
print('MAE:', mean_absolute_error(y_test, Prediction_2))

print("RMSE for Training Data: ", sqrt(mean_squared_error(y_train, model_2.predict(x_train))))
print("RMSE for Testing Data: ", sqrt(mean_squared_error(y_test, Prediction_2)))

print('Coefficient of determination (R^2) for testing: %.2f'
        % r2_score(y_test, Prediction_2))

print('Coefficient of determination (R^2) for training: %.2f'
        % r2_score(y_train, model_2.predict(x_train)))
# Out:
# MSE: 98.4351027258233
# MAE: 8.020948402271692
# RMSE for Training Data:  9.783704361050363
# RMSE for Testing Data:  9.921446604493887
# Coefficient of determination (R^2) for testing: 0.76
# Coefficient of determination (R^2) for training: 0.76

# %%
y_train = np.squeeze(y_train)
y_pred_train = model_2.predict(x_train)

y_pred_train = np.reshape(y_pred_train, (1,3380))
y_pred_train = np.squeeze(y_pred_train)
print(y_train.shape, model_2.predict(x_train).shape)
# Out:
# (3380,) (3380, 1)

# %%
y_test = np.squeeze(y_test)
Prediction_2 = np.squeeze(Prediction_2)
print(y_test.shape, Prediction_2.shape)
# Out:
# (846,) (846,)

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(y_test, Prediction_2, alpha=1.0, marker="*")
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', color='red', lw = 3)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Testing Data')
# Out:
# C:\Users\kunsa\AppData\Local\Programs\Python\Python36\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Testing Data')

# %% [markdown]
# Model 3: Naive Bayes Model

# %%
from sklearn.naive_bayes import GaussianNB
model_3 = GaussianNB()
model_3.fit(x_train, y_train)
Prediction_3 = model_3.predict(x_test)

# %%
print('MSE:', mean_squared_error(y_test, Prediction_3))
print('MAE:', mean_absolute_error(y_test, Prediction_3))

print("RMSE for Training Data: ", sqrt(mean_squared_error(y_train, model_3.predict(x_train))))
print("RMSE for Testing Data: ", sqrt(mean_squared_error(y_test, Prediction_3)))

print('Coefficient of determination (R^2) for testing : %.2f'
        % r2_score(y_test, Prediction_3))
print('Coefficient of determination (R^2)for training: %.2f'
        % r2_score(y_train, model_3.predict(x_train)))
# Out:
# MSE: 152.27186761229314
# MAE: 8.869976359338061
# RMSE for Training Data:  11.646760984072712
# RMSE for Testing Data:  12.33984876780478
# Coefficient of determination (R^2) for testing : 0.63
# Coefficient of determination (R^2)for training: 0.66

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(y_train, model_3.predict(x_train), alpha=1.0)
plt.plot([y_train.min(), y_train.max()], [y_train.min(), y_train.max()], 'k--', color='red', lw = 3)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Training Data')
# Out:
# C:\Users\kunsa\AppData\Local\Programs\Python\Python36\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Training Data')

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(y_test, Prediction_3, alpha=1.0, marker="*")
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', color='red', lw = 3)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Testing Data')
# Out:
# C:\Users\kunsa\AppData\Local\Programs\Python\Python36\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Testing Data')
